# %% [markdown]
# # Graphs

# %% [markdown]
# ## Best Base Pairs Statistics (stat_bp_best.out)

# %% [markdown]
# ### Number of base pairs not in any functional coding sequence

# %%
import pandas as pd
import matplotlib.pyplot as plt

#INPUT_ROOT_DIR = "..//Dropbox//Freiburg Masters Semesters//Thesis//Results"
INPUT_ROOT_DIR = r"..//Results//"
OUTPUT_ROOT_DIR = r"..//Results//Graphics//"

print("Reading in the data...")
# Read in the data from the five seeds
bp_best_names=['generation','nbp not in any CDS', 'nbp not in any functional CDS', 'nbp not in any non-functional CDS', 'nbp in any RNA', 'nbp not included in any coding RNA', 'nbp not included in any non-coding RNA', 'num non-essential bp', 'num non-essential bp including non-funct genes']
df_seed01_bp_best = pd.read_csv(INPUT_ROOT_DIR + "seed01//control//stats//stat_bp_best.out", skiprows=17, delim_whitespace=True, header=0, names=bp_best_names)
df_seed02_bp_best = pd.read_csv(INPUT_ROOT_DIR + "seed02//control//stats//stat_bp_best.out", skiprows=17, delim_whitespace=True, header=0, names=bp_best_names)
df_seed03_bp_best = pd.read_csv(INPUT_ROOT_DIR + "seed03//control//stats//stat_bp_best.out", skiprows=17, delim_whitespace=True, header=0, names=bp_best_names)
df_seed04_bp_best = pd.read_csv(INPUT_ROOT_DIR + "seed04//control//stats//stat_bp_best.out", skiprows=17, delim_whitespace=True, header=0, names=bp_best_names)
df_seed05_bp_best = pd.read_csv(INPUT_ROOT_DIR + "seed05//control//stats//stat_bp_best.out", skiprows=17, delim_whitespace=True, header=0, names=bp_best_names)

print("complete")
# Out:
# Reading in the data...
# complete

# %% [markdown]
# #### Plot the number of base pairs not in any coding sequence

# %%
# Plot them all to the same figure
plot1_ax = df_seed01_bp_best.plot(x = 'generation', y = 'nbp not in any CDS', label='seed 1', figsize=(20,20))
df_seed02_bp_best.plot(x = 'generation', y = 'nbp not in any CDS', label='seed 2', ax=plot1_ax)
df_seed03_bp_best.plot(x = 'generation', y = 'nbp not in any CDS', label='seed 3', ax=plot1_ax)
df_seed04_bp_best.plot(x = 'generation', y = 'nbp not in any CDS', label='seed 4', ax=plot1_ax)
df_seed05_bp_best.plot(x = 'generation', y = 'nbp not in any CDS', label='seed 5', ax=plot1_ax)
plot1_ax.set_title("Control Condition - Num basepairs not in any CDS")
fig1 = plot1_ax.get_figure()
fig1.savefig(OUTPUT_ROOT_DIR + "control_nbp_not_in_any_CDS.png")

# %% [markdown]
# ### Number of base pairs not in any functional coding sequence

# %%
# Clear the previous figure
plt.close()
plot2_ax = df_seed01_bp_best.plot(x = 'generation', y = 'nbp not in any functional CDS', label='seed 1', figsize=(20,20))
df_seed02_bp_best.plot(x='generation', y='nbp not in any functional CDS', label='seed 2', ax=plot2_ax)
df_seed03_bp_best.plot(x='generation', y='nbp not in any functional CDS', label='seed 3', ax=plot2_ax)
df_seed04_bp_best.plot(x='generation', y='nbp not in any functional CDS', label='seed 4', ax=plot2_ax)
df_seed05_bp_best.plot(x='generation', y='nbp not in any functional CDS', label='seed 5', ax=plot2_ax)
plot2_ax.set_title("Control Condition - Num base pairs not in any functional CDS")
fig2 = plot2_ax.get_figure()
fig2.savefig(OUTPUT_ROOT_DIR + "control_nbp_not_in_any_functional_CDS.png")

# %% [markdown]
# ### Number of base pairs not in any non-functional coding sequence

# %%
plt.clf()
plot3_ax = df_seed01_bp_best.plot(x = 'generation', y = 'nbp not in any non-functional CDS', label='seed 1', figsize=(20,20))
df_seed02_bp_best.plot(x = 'generation', y = 'nbp not in any non-functional CDS', label='seed 2', ax=plot3_ax)
df_seed03_bp_best.plot(x = 'generation', y = 'nbp not in any non-functional CDS', label='seed 3', ax=plot3_ax)
df_seed04_bp_best.plot(x = 'generation', y = 'nbp not in any non-functional CDS', label='seed 4', ax=plot3_ax)
df_seed05_bp_best.plot(x = 'generation', y = 'nbp not in any non-functional CDS', label='seed 5', ax=plot3_ax)
plot3_ax.set_title("Control Condition - Num base pairs not in any non-functional CDS")
fig3 = plot3_ax.get_figure()
fig3.savefig(OUTPUT_ROOT_DIR + "control_nbp_not_in_any_non-functional_CDS.png")

# %% [markdown]
# ## Global Gene Statistics (stat_genes_glob.out)

# %% [markdown]
# Read in the data

# %%
# Read in data from five seeds 
print("Reading in data...")
genes_glob_names=['generation', 'num coding RNAs', 'num non-coding RNAs', 'avg coding RNA size', 'avg non-coding RNA size', 'num functional genes', 'num non-functional genes', 'avg functional gene size', 'avg non-functional gene size']
df_seed01_stat_genes_glob_control = pd.read_csv(INPUT_ROOT_DIR + "seed01//control//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed02_stat_genes_glob_control = pd.read_csv(INPUT_ROOT_DIR + "seed02//control//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed03_stat_genes_glob_control = pd.read_csv(INPUT_ROOT_DIR + "seed03//control//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed04_stat_genes_glob_control = pd.read_csv(INPUT_ROOT_DIR + "seed04//control//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed05_stat_genes_glob_control = pd.read_csv(INPUT_ROOT_DIR + "seed05//control//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
print("Done!")
# Out:
# Reading in data...
# Done!

# %% [markdown]
# Plot the results

# %%
plot4_ax = df_seed01_stat_genes_glob_control.plot(x='generation', y='num coding RNAs', label='seed 1', figsize=(20,20))
df_seed02_stat_genes_glob_control.plot(x='generation', y='num coding RNAs', label='seed 2', ax=plot4_ax)
df_seed03_stat_genes_glob_control.plot(x='generation', y='num coding RNAs', label='seed 3', ax=plot4_ax)
df_seed04_stat_genes_glob_control.plot(x='generation', y='num coding RNAs', label='seed 4', ax=plot4_ax)
df_seed05_stat_genes_glob_control.plot(x='generation', y='num coding RNAs', label='seed 5', ax=plot4_ax)
plot4_ax.set_title("Control Condition - Number of coding RNAs")
fig4 = plot4_ax.get_figure()
fig4.savefig(OUTPUT_ROOT_DIR + "control_num_coding_RNAs.png")

# %%
plot5_ax = df_seed01_stat_genes_glob_control.plot(x='generation', y='num non-coding RNAs', label='seed 1', figsize=(20,20))
df_seed02_stat_genes_glob_control.plot(x='generation', y='num non-coding RNAs', label='seed 2', ax=plot5_ax)
df_seed03_stat_genes_glob_control.plot(x='generation', y='num non-coding RNAs', label='seed 3', ax=plot5_ax)
df_seed04_stat_genes_glob_control.plot(x='generation', y='num non-coding RNAs', label='seed 4', ax=plot5_ax)
df_seed05_stat_genes_glob_control.plot(x='generation', y='num non-coding RNAs', label='seed 5', ax=plot5_ax)
plot4_ax.set_title("Control Condition - Number of non-coding RNAs")
fig5 = plot5_ax.get_figure()
fig5.savefig(OUTPUT_ROOT_DIR + "control_num_non-coding_RNAs.png")

# %% [markdown]
# ### Create a boxplot of the number of functional genes across all conditions (control, m+, m-, n+, n-, sel+, sel-).
# First read in the same stats files for all other conditions

# %%
# Create a boxplot of the number of functional genes across all conditions (control, m+, m-, n+, n-, sel+, sel-)
# First read in the same stats files for all other conditions
print("Reading in the data...")
df_seed01_stat_genes_glob_mut_up = pd.read_csv(INPUT_ROOT_DIR + "seed01//mut_up//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed01_stat_genes_glob_mut_down = pd.read_csv(INPUT_ROOT_DIR + "seed01//mut_down//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed01_stat_genes_glob_pop_up = pd.read_csv(INPUT_ROOT_DIR + "seed01//pop_up//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed01_stat_genes_glob_pop_down = pd.read_csv(INPUT_ROOT_DIR + "seed01//pop_down//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed01_stat_genes_glob_selection_up = pd.read_csv(INPUT_ROOT_DIR + "seed01//selection_up//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
df_seed01_stat_genes_glob_selection_down = pd.read_csv(INPUT_ROOT_DIR + "seed01//selection_down//stats//stat_genes_glob.out", skiprows=14, delim_whitespace=True, header=0, names=genes_glob_names)
print("done.")
# Out:
# Reading in the data...
# done.

# %% [markdown]
# We need to have one DataFrame to give to .boxplot() so we will add an additional column with the experimental condition and then combine all of the DataFrames into one DataFrame.

# %%
df_seed01_stat_genes_glob_mut_up["condition"] = "mutation+"
df_seed01_stat_genes_glob_mut_down["condition"] = "mutation-"
df_seed01_stat_genes_glob_pop_up["condition"] = "population+"
df_seed01_stat_genes_glob_pop_down["condition"] = "population-"
df_seed01_stat_genes_glob_selection_up["condition"] = "selection+"
df_seed01_stat_genes_glob_selection_down["condition"] = "selection-"
df_seed01_stat_genes_glob_control["condition"] = "control"

allData = pd.DataFrame(pd.concat([df_seed01_stat_genes_glob_control, df_seed01_stat_genes_glob_mut_up, df_seed01_stat_genes_glob_mut_down, df_seed01_stat_genes_glob_pop_up, df_seed01_stat_genes_glob_pop_down, df_seed01_stat_genes_glob_selection_up, df_seed01_stat_genes_glob_selection_down]))

# %% [markdown]
# Now plot the combined data.

# %%
plot5_ax = allData.boxplot(column='num functional genes', by='condition', figsize=(20,20))
plot5_ax.set_title("Seed 1 - Number of functional genes across conditions.")
fig5 = plot5_ax.get_figure()
fig5.savefig(OUTPUT_ROOT_DIR + "seed01_num_functional_genes_all_conditions.png")

# %% [markdown]
# ## Comparing Genome Length

# %% [markdown]
# We should compare the length of the genomes for all seven conditions and see if changing the parameters had an effect on the length of the genome.
# Following the method of the paper "How to Reduce a Genome?", we compute the average length across all seeds.

# %% [markdown]
# ##### We begin with the Control condition.

# %%
# Seed01
f_c_1 = open(INPUT_ROOT_DIR + "seed01//control//best_last_org.txt", "r")
txt_c_1 = f_c_1.read()
size_c_1 = len(txt_c_1)
f_c_1.close()

# Seed02
f_c_2 = open(INPUT_ROOT_DIR + "seed02//control//best_last_org.txt", "r")
txt_c_2 = f_c_2.read()
size_c_2 = len(txt_c_2)
f_c_2.close()

# Seed03
f_c_3 = open(INPUT_ROOT_DIR + "seed03//control//best_last_org.txt", "r")
txt_c_3 = f_c_3.read()
size_c_3 = len(txt_c_3)
f_c_3.close()

# Seed04
f_c_4 = open(INPUT_ROOT_DIR + "seed04//control//best_last_org.txt", "r")
txt_c_4 = f_c_4.read()
size_c_4 = len(txt_c_4)
f_c_4.close()

# Seed05
f_c_5 = open(INPUT_ROOT_DIR + "seed05//control//best_last_org.txt", "r")
txt_c_5 = f_c_5.read()
size_c_5 = len(txt_c_5)
f_c_5.close()

# %% [markdown]
# Now that we have the sizes of all of the best organisms, we can find the average:

# %%
# compute the average size
avg_c = (size_c_1 + size_c_2 + size_c_3 + size_c_4 + size_c_5) / 5
print("The average size of the genome for the control condition across all seeds is", avg_c, "base pairs.")
# Out:
# The average size of the genome for the control condition across all seeds is 13400.2 base pairs.

# %% [markdown]
# #### Compute this statistic for the remaining conditions.

# %% [markdown]
# ##### mutation rate up

# %%
# Seed01
f_mu_1 = open(INPUT_ROOT_DIR + "seed01//mut_up//best_last_org.txt", "r")
txt_mu_1 = f_mu_1.read()
size_mu_1 = len(txt_mu_1)
f_mu_1.close()

# Seed02
f_mu_2 = open(INPUT_ROOT_DIR + "seed02//mut_up//best_last_org.txt", "r")
txt_mu_2 = f_mu_2.read()
size_mu_2 = len(txt_mu_2)
f_mu_2.close()

# Seed03
f_mu_3 = open(INPUT_ROOT_DIR + "seed03//mut_up//best_last_org.txt", "r")
txt_mu_3 = f_mu_3.read()
size_mu_3 = len(txt_mu_3)
f_mu_3.close()

# Seed04
f_mu_4 = open(INPUT_ROOT_DIR + "seed04//mut_up//best_last_org.txt", "r")
txt_mu_4 = f_mu_4.read()
size_mu_4 = len(txt_mu_4)
f_mu_4.close()

# Seed05
f_mu_5 = open(INPUT_ROOT_DIR + "seed05//mut_up//best_last_org.txt", "r")
txt_mu_5 = f_mu_5.read()
size_mu_5 = len(txt_mu_5)
f_mu_5.close()

avg_mu = (size_mu_1 + size_mu_2 + size_mu_3 + size_mu_4 + size_mu_5) / 5

# %% [markdown]
# ##### mutation rate down

# %%
# Seed01
f_md_1 = open(INPUT_ROOT_DIR + "seed01//mut_down//best_last_org.txt", "r")
txt_md_1 = f_md_1.read()
size_md_1 = len(txt_md_1)
f_md_1.close()

# Seed02
f_md_2 = open(INPUT_ROOT_DIR + "seed02//mut_down//best_last_org.txt", "r")
txt_md_2 = f_md_2.read()
size_md_2 = len(txt_md_2)
f_md_2.close()

# Seed03
f_md_3 = open(INPUT_ROOT_DIR + "seed03//mut_down//best_last_org.txt", "r")
txt_md_3 = f_md_3.read()
size_md_3 = len(txt_md_3)
f_md_3.close()

# Seed04
f_md_4 = open(INPUT_ROOT_DIR + "seed04//mut_down//best_last_org.txt", "r")
txt_md_4 = f_md_4.read()
size_md_4 = len(txt_md_4)
f_md_4.close()

# Seed05
f_md_5 = open(INPUT_ROOT_DIR + "seed05//mut_down//best_last_org.txt", "r")
txt_md_5 = f_md_5.read()
size_md_5 = len(txt_md_5)
f_md_5.close()

avg_md = (size_md_1 + size_md_2 + size_md_3 + size_md_4 + size_md_5) / 5

# %% [markdown]
# ##### population up

# %%
# Seed01
f_pu_1 = open(INPUT_ROOT_DIR + "seed01//pop_up//best_last_org.txt", "r")
txt_pu_1 = f_pu_1.read()
size_pu_1 = len(txt_pu_1)
f_pu_1.close()

# Seed02
f_pu_2 = open(INPUT_ROOT_DIR + "seed02//pop_up//best_last_org.txt", "r")
txt_pu_2 = f_pu_2.read()
size_pu_2 = len(txt_pu_2)
f_pu_2.close()

# Seed03
f_pu_3 = open(INPUT_ROOT_DIR + "seed03//pop_up//best_last_org.txt", "r")
txt_pu_3 = f_pu_3.read()
size_pu_3 = len(txt_pu_3)
f_pu_3.close()

# Seed04
f_pu_4 = open(INPUT_ROOT_DIR + "seed04//pop_up//best_last_org.txt", "r")
txt_pu_4 = f_pu_4.read()
size_pu_4 = len(txt_pu_4)
f_pu_4.close()

# Seed05
f_pu_5 = open(INPUT_ROOT_DIR + "seed05//pop_up//best_last_org.txt", "r")
txt_pu_5 = f_pu_5.read()
size_pu_5 = len(txt_pu_5)
f_pu_5.close()

avg_pu = (size_pu_1 + size_pu_2 + size_pu_3 + size_pu_4 + size_pu_5) / 5

# %% [markdown]
# ##### population down

# %%
# Seed01
f_pd_1 = open(INPUT_ROOT_DIR + "seed01//pop_down//best_last_org.txt", "r")
txt_pd_1 = f_pd_1.read()
size_pd_1 = len(txt_pd_1)
f_pd_1.close()

# Seed02
f_pd_2 = open(INPUT_ROOT_DIR + "seed02//pop_down//best_last_org.txt", "r")
txt_pd_2 = f_pd_2.read()
size_pd_2 = len(txt_pd_2)
f_pd_2.close()

# Seed03
f_pd_3 = open(INPUT_ROOT_DIR + "seed03//pop_down//best_last_org.txt", "r")
txt_pd_3 = f_pd_3.read()
size_pd_3 = len(txt_pd_3)
f_pd_3.close()

f_pd_4 = open(INPUT_ROOT_DIR + "seed04//pop_down//best_last_org.txt", "r")
txt_pd_4 = f_pd_4.read()
size_pd_4 = len(txt_pd_4)
f_pd_4.close()

# Seed05
f_pd_5 = open(INPUT_ROOT_DIR + "seed05//pop_down//best_last_org.txt", "r")
txt_pd_5 = f_pd_5.read()
size_pd_5 = len(txt_pd_5)
f_pd_5.close()

avg_pd = (size_pd_1 + size_pd_2 + size_pd_3 + size_pd_4 + size_pd_5) / 5

# %% [markdown]
# ##### selection up

# %%
# Seed01
f_su_1 = open(INPUT_ROOT_DIR + "seed01//selection_up//best_last_org.txt", "r")
txt_su_1 = f_su_1.read()
size_su_1 = len(txt_su_1)
f_su_1.close()

# Seed02
f_su_2 = open(INPUT_ROOT_DIR + "seed02//selection_up//best_last_org.txt", "r")
txt_su_2 = f_su_2.read()
size_su_2 = len(txt_su_2)
f_su_2.close()

# Seed03
f_su_3 = open(INPUT_ROOT_DIR + "seed03//selection_up//best_last_org.txt", "r")
txt_su_3 = f_su_3.read()
size_su_3 = len(txt_su_3)
f_su_3.close()

# Seed04
f_su_4 = open(INPUT_ROOT_DIR + "seed04//selection_up//best_last_org.txt", "r")
txt_su_4 = f_su_4.read()
size_su_4 = len(txt_su_4)
f_su_4.close()

# Seed05
f_su_5 = open(INPUT_ROOT_DIR + "seed05//selection_up//best_last_org.txt", "r")
txt_su_5 = f_su_5.read()
size_su_5 = len(txt_su_5)
f_su_5.close()

avg_su = (size_su_1 + size_su_2 + size_su_3 + size_su_4 + size_su_5) / 5

# %% [markdown]
# ##### selection down

# %%
# Seed01
f_sd_1 = open(INPUT_ROOT_DIR + "seed01//selection_down//best_last_org.txt", "r")
txt_sd_1 = f_sd_1.read()
size_sd_1 = len(txt_sd_1)
f_sd_1.close()

# Seed02
f_sd_2 = open(INPUT_ROOT_DIR + "seed02//selection_down//best_last_org.txt", "r")
txt_sd_2 = f_sd_2.read()
size_sd_2 = len(txt_sd_2)
f_sd_2.close()

# Seed03
f_sd_3 = open(INPUT_ROOT_DIR + "seed03//selection_down//best_last_org.txt", "r")
txt_sd_3 = f_sd_3.read()
size_sd_3 = len(txt_sd_3)
f_sd_3.close()

# Seed04
f_sd_4 = open(INPUT_ROOT_DIR + "seed04//selection_down//best_last_org.txt", "r")
txt_sd_4 = f_sd_4.read()
size_sd_4 = len(txt_sd_4)
f_sd_4.close()

# Seed05
f_sd_5 = open(INPUT_ROOT_DIR + "seed05//selection_down//best_last_org.txt", "r")
txt_sd_5 = f_sd_5.read()
size_sd_5 = len(txt_sd_5)
f_sd_5.close()

avg_sd = (size_sd_1 + size_sd_2 + size_sd_3 + size_sd_4 + size_sd_5) / 5

# %% [markdown]
# ### Overall results

# %%
overall_avg = (avg_c + avg_mu + avg_md + avg_pu + avg_pd + avg_su + avg_sd) / 7
print("Overall average:",overall_avg)
# Out:
# Overall average: 13337.42857142857

# %% [markdown]
# As in the paper, these results should be compared with the wild-type at the beginning of the experiment.

# %%
f_wild_typ = open("best_last_org.txt", "r")
size_wild = len(f_wild_typ.read())
print("Wild-type has", size_wild, "base pairs.")
# Out:
# Wild-type has 13238 base pairs.
